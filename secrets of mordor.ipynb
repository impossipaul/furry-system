# %% [markdown]
# # This is a heading
# * this is a bullet
# * this is another bullet
#
# keep it secret, keep it safe
#
# you shall not pass
#
# po-tay-toes

# %%
print ("Gandalf for President.")
# Out:
# Gandalf for President.
